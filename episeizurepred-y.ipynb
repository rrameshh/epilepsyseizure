# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/epileptic-seizure-recognition/Epileptic Seizure Recognition.csv

# %%
data_path = "/kaggle/input/epileptic-seizure-recognition/Epileptic Seizure Recognition.csv"
import pandas as pd
import os
df=pd.read_csv(data_path)
df.head()
# Out:
#       Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Flatten
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
y = df['y']
df = df.drop(['Unnamed'], axis=1)

# %%
df = df.drop(['y'], axis=1)
X = []
for i, row in df.iterrows():
    tmp_x = []
    for elem in row.tolist():
         tmp_x.append([elem])
    X.append(tmp_x)

# %%
for i in range(y.shape[0]):
    if y[i]!=1:
        y[i]=0

# %%
X = np.array(X)

# %%
# Scaling the data
#scaler = StandardScaler()
#X_scaled = scaler.fit_transform(X)

model = Sequential()
model.add(LSTM(64, input_shape=(178,1), return_sequences=True))
model.add(LSTM(32))
model.add(Flatten())
model.add(Dense(250, activation='relu'))

model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=100, batch_size=128, verbose=2)
# Out:
# Epoch 1/100
# 72/72 - 24s - loss: 0.2886 - accuracy: 0.8809 - val_loss: 0.1817 - val_accuracy: 0.9487 - 24s/epoch - 337ms/step
# Epoch 2/100
# 72/72 - 19s - loss: 0.1599 - accuracy: 0.9440 - val_loss: 0.1771 - val_accuracy: 0.9317 - 19s/epoch - 257ms/step
# Epoch 3/100
# 72/72 - 19s - loss: 0.1355 - accuracy: 0.9439 - val_loss: 0.1301 - val_accuracy: 0.9496 - 19s/epoch - 258ms/step
# Epoch 4/100
# 72/72 - 18s - loss: 0.1004 - accuracy: 0.9625 - val_loss: 0.1200 - val_accuracy: 0.9635 - 18s/epoch - 252ms/step
# Epoch 5/100
# 72/72 - 18s - loss: 0.1029 - accuracy: 0.9610 - val_loss: 0.1203 - val_accuracy: 0.9604 - 18s/epoch - 254ms/step
# Epoch 6/100
# 72/72 - 18s - loss: 0.0840 - accuracy: 0.9715 - val_loss: 0.0943 - val_accuracy: 0.9691 - 18s/epoch - 251ms/step
# Epoch 7/100
# 72/72 - 18s - loss: 0.0858 - accuracy: 0.9701 - val_loss: 0.1056 - val_accuracy: 0.9639 - 18s/epoch - 251ms/step
# Epoch 8/100
# 72/72 - 19s - loss: 0.0953 - accuracy: 0.9658 - val_loss: 0.1037 - val_accuracy: 0.9674 - 19s/epoch - 258ms/step
# Epoch 9/100
# 72/72 - 18s - loss: 0.0799 - accuracy: 0.9728 - val_loss: 0.0984 - val_accuracy: 0.9726 - 18s/epoch - 251ms/step
# Epoch 10/100
# 72/72 - 19s - loss: 0.0845 - accuracy: 0.9720 - val_loss: 0.1028 - val_accuracy: 0.9670 - 19s/epoch - 257ms/step
# Epoch 11/100
# 72/72 - 18s - loss: 0.0732 - accuracy: 0.9735 - val_loss: 0.0884 - val_accuracy: 0.9726 - 18s/epoch - 255ms/step
# Epoch 12/100
# 72/72 - 19s - loss: 0.0585 - accuracy: 0.9799 - val_loss: 0.0819 - val_accuracy: 0.9761 - 19s/epoch - 257ms/step
# Epoch 13/100
# 72/72 - 18s - loss: 0.0562 - accuracy: 0.9808 - val_loss: 0.0755 - val_accuracy: 0.9778 - 18s/epoch - 255ms/step
# Epoch 14/100
# 72/72 - 19s - loss: 0.0544 - accuracy: 0.9815 - val_loss: 0.0732 - val_accuracy: 0.9791 - 19s/epoch - 264ms/step
# Epoch 15/100
# 72/72 - 19s - loss: 0.0504 - accuracy: 0.9828 - val_loss: 0.0769 - val_accuracy: 0.9752 - 19s/epoch - 264ms/step
# Epoch 16/100
# 72/72 - 19s - loss: 0.0506 - accuracy: 0.9814 - val_loss: 0.0672 - val_accuracy: 0.9796 - 19s/epoch - 264ms/step
# Epoch 17/100
# 72/72 - 19s - loss: 0.0483 - accuracy: 0.9833 - val_loss: 0.0816 - val_accuracy: 0.9743 - 19s/epoch - 267ms/step
# Epoch 18/100
# 72/72 - 19s - loss: 0.0463 - accuracy: 0.9830 - val_loss: 0.1138 - val_accuracy: 0.9652 - 19s/epoch - 260ms/step
# Epoch 19/100
# 72/72 - 19s - loss: 0.0601 - accuracy: 0.9776 - val_loss: 0.0720 - val_accuracy: 0.9796 - 19s/epoch - 261ms/step
# Epoch 20/100
# 72/72 - 18s - loss: 0.0407 - accuracy: 0.9865 - val_loss: 0.0662 - val_accuracy: 0.9813 - 18s/epoch - 254ms/step
# Epoch 21/100
# 72/72 - 18s - loss: 0.0398 - accuracy: 0.9853 - val_loss: 0.0848 - val_accuracy: 0.9748 - 18s/epoch - 255ms/step
# Epoch 22/100
# 72/72 - 18s - loss: 0.0355 - accuracy: 0.9870 - val_loss: 0.0711 - val_accuracy: 0.9809 - 18s/epoch - 253ms/step
# Epoch 23/100
# 72/72 - 18s - loss: 0.0323 - accuracy: 0.9873 - val_loss: 0.0708 - val_accuracy: 0.9796 - 18s/epoch - 249ms/step
# Epoch 24/100
# 72/72 - 18s - loss: 0.0311 - accuracy: 0.9884 - val_loss: 0.0772 - val_accuracy: 0.9783 - 18s/epoch - 250ms/step
# Epoch 25/100
# 72/72 - 18s - loss: 0.0357 - accuracy: 0.9877 - val_loss: 0.0705 - val_accuracy: 0.9796 - 18s/epoch - 250ms/step
# Epoch 26/100
# 72/72 - 18s - loss: 0.0332 - accuracy: 0.9880 - val_loss: 0.0709 - val_accuracy: 0.9830 - 18s/epoch - 255ms/step
# Epoch 27/100
# 72/72 - 18s - loss: 0.0328 - accuracy: 0.9879 - val_loss: 0.0739 - val_accuracy: 0.9817 - 18s/epoch - 252ms/step
# Epoch 28/100
# 72/72 - 19s - loss: 0.0314 - accuracy: 0.9890 - val_loss: 0.0857 - val_accuracy: 0.9735 - 19s/epoch - 265ms/step
# Epoch 29/100
# 72/72 - 19s - loss: 0.0306 - accuracy: 0.9893 - val_loss: 0.0950 - val_accuracy: 0.9765 - 19s/epoch - 260ms/step
# Epoch 30/100
# 72/72 - 19s - loss: 0.0279 - accuracy: 0.9900 - val_loss: 0.0608 - val_accuracy: 0.9804 - 19s/epoch - 259ms/step
# Epoch 31/100
# 72/72 - 19s - loss: 0.0346 - accuracy: 0.9875 - val_loss: 0.0658 - val_accuracy: 0.9791 - 19s/epoch - 265ms/step
# Epoch 32/100
# 72/72 - 19s - loss: 0.0343 - accuracy: 0.9880 - val_loss: 0.0643 - val_accuracy: 0.9791 - 19s/epoch - 262ms/step
# Epoch 33/100
# 72/72 - 19s - loss: 0.0302 - accuracy: 0.9897 - val_loss: 0.0657 - val_accuracy: 0.9778 - 19s/epoch - 267ms/step
# Epoch 34/100
# 72/72 - 19s - loss: 0.0215 - accuracy: 0.9916 - val_loss: 0.0676 - val_accuracy: 0.9796 - 19s/epoch - 265ms/step
# Epoch 35/100
# 72/72 - 19s - loss: 0.0239 - accuracy: 0.9915 - val_loss: 0.0674 - val_accuracy: 0.9765 - 19s/epoch - 263ms/step
# Epoch 36/100
# 72/72 - 19s - loss: 0.0271 - accuracy: 0.9911 - val_loss: 0.0782 - val_accuracy: 0.9809 - 19s/epoch - 263ms/step
# Epoch 37/100
# 72/72 - 19s - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.0742 - val_accuracy: 0.9809 - 19s/epoch - 259ms/step
# Epoch 38/100
# 72/72 - 19s - loss: 0.0201 - accuracy: 0.9938 - val_loss: 0.0722 - val_accuracy: 0.9787 - 19s/epoch - 262ms/step
# Epoch 39/100
# 72/72 - 19s - loss: 0.0251 - accuracy: 0.9903 - val_loss: 0.0652 - val_accuracy: 0.9809 - 19s/epoch - 257ms/step
# Epoch 40/100
# 72/72 - 19s - loss: 0.0182 - accuracy: 0.9929 - val_loss: 0.0645 - val_accuracy: 0.9835 - 19s/epoch - 257ms/step
# Epoch 41/100
# 72/72 - 19s - loss: 0.0173 - accuracy: 0.9940 - val_loss: 0.0735 - val_accuracy: 0.9809 - 19s/epoch - 262ms/step
# Epoch 42/100
# 72/72 - 18s - loss: 0.0239 - accuracy: 0.9922 - val_loss: 0.0723 - val_accuracy: 0.9765 - 18s/epoch - 257ms/step
# Epoch 43/100
# 72/72 - 19s - loss: 0.0285 - accuracy: 0.9887 - val_loss: 0.0661 - val_accuracy: 0.9817 - 19s/epoch - 262ms/step
# Epoch 44/100
# 72/72 - 18s - loss: 0.0232 - accuracy: 0.9916 - val_loss: 0.0641 - val_accuracy: 0.9804 - 18s/epoch - 253ms/step
# Epoch 45/100
# 72/72 - 19s - loss: 0.0223 - accuracy: 0.9924 - val_loss: 0.0803 - val_accuracy: 0.9800 - 19s/epoch - 262ms/step
# Epoch 46/100
# 72/72 - 19s - loss: 0.0215 - accuracy: 0.9927 - val_loss: 0.0646 - val_accuracy: 0.9826 - 19s/epoch - 260ms/step
# Epoch 47/100
# 72/72 - 19s - loss: 0.0136 - accuracy: 0.9949 - val_loss: 0.0771 - val_accuracy: 0.9796 - 19s/epoch - 262ms/step
# Epoch 48/100
# 72/72 - 19s - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.0701 - val_accuracy: 0.9835 - 19s/epoch - 265ms/step
# Epoch 49/100
# 72/72 - 19s - loss: 0.0122 - accuracy: 0.9954 - val_loss: 0.0780 - val_accuracy: 0.9830 - 19s/epoch - 260ms/step
# Epoch 50/100
# 72/72 - 19s - loss: 0.0263 - accuracy: 0.9903 - val_loss: 0.0622 - val_accuracy: 0.9822 - 19s/epoch - 265ms/step
# Epoch 51/100
# 72/72 - 19s - loss: 0.0134 - accuracy: 0.9950 - val_loss: 0.0810 - val_accuracy: 0.9843 - 19s/epoch - 261ms/step
# Epoch 52/100
# 72/72 - 19s - loss: 0.0156 - accuracy: 0.9943 - val_loss: 0.0707 - val_accuracy: 0.9830 - 19s/epoch - 265ms/step
# Epoch 53/100
# 72/72 - 19s - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.0827 - val_accuracy: 0.9835 - 19s/epoch - 261ms/step
# Epoch 54/100
# 72/72 - 18s - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.0931 - val_accuracy: 0.9817 - 18s/epoch - 256ms/step
# Epoch 55/100
# 72/72 - 19s - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0795 - val_accuracy: 0.9835 - 19s/epoch - 266ms/step
# Epoch 56/100
# 72/72 - 18s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0868 - val_accuracy: 0.9830 - 18s/epoch - 255ms/step
# Epoch 57/100
# 72/72 - 19s - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.0882 - val_accuracy: 0.9843 - 19s/epoch - 258ms/step
# Epoch 58/100
# 72/72 - 18s - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.0918 - val_accuracy: 0.9839 - 18s/epoch - 254ms/step
# Epoch 59/100
# 72/72 - 18s - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0915 - val_accuracy: 0.9835 - 18s/epoch - 255ms/step
# Epoch 60/100
# 72/72 - 19s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0932 - val_accuracy: 0.9861 - 19s/epoch - 257ms/step
# Epoch 61/100
# 72/72 - 18s - loss: 9.9311e-04 - accuracy: 0.9998 - val_loss: 0.0968 - val_accuracy: 0.9848 - 18s/epoch - 249ms/step
# Epoch 62/100
# 72/72 - 19s - loss: 7.9008e-04 - accuracy: 0.9998 - val_loss: 0.0957 - val_accuracy: 0.9848 - 19s/epoch - 263ms/step
# Epoch 63/100
# 72/72 - 19s - loss: 6.9940e-04 - accuracy: 0.9998 - val_loss: 0.0997 - val_accuracy: 0.9852 - 19s/epoch - 259ms/step
# Epoch 64/100
# 72/72 - 19s - loss: 6.0858e-04 - accuracy: 0.9998 - val_loss: 0.0992 - val_accuracy: 0.9848 - 19s/epoch - 267ms/step
# Epoch 65/100
# 72/72 - 19s - loss: 0.0281 - accuracy: 0.9913 - val_loss: 0.0843 - val_accuracy: 0.9778 - 19s/epoch - 262ms/step
# Epoch 66/100
# 72/72 - 19s - loss: 0.0282 - accuracy: 0.9895 - val_loss: 0.0576 - val_accuracy: 0.9809 - 19s/epoch - 263ms/step
# Epoch 67/100
# 72/72 - 19s - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.0630 - val_accuracy: 0.9796 - 19s/epoch - 266ms/step
# Epoch 68/100
# 72/72 - 19s - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.0821 - val_accuracy: 0.9835 - 19s/epoch - 261ms/step
# Epoch 69/100
# 72/72 - 19s - loss: 0.0103 - accuracy: 0.9960 - val_loss: 0.0761 - val_accuracy: 0.9830 - 19s/epoch - 261ms/step
# Epoch 70/100
# 72/72 - 19s - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0915 - val_accuracy: 0.9809 - 19s/epoch - 258ms/step
# Epoch 71/100
# 72/72 - 19s - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0828 - val_accuracy: 0.9822 - 19s/epoch - 261ms/step
# Epoch 72/100
# 72/72 - 19s - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.1021 - val_accuracy: 0.9804 - 19s/epoch - 259ms/step
# Epoch 73/100
# 72/72 - 18s - loss: 0.0091 - accuracy: 0.9972 - val_loss: 0.0717 - val_accuracy: 0.9839 - 18s/epoch - 256ms/step
# Epoch 74/100
# 72/72 - 19s - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.0984 - val_accuracy: 0.9791 - 19s/epoch - 262ms/step
# Epoch 75/100
# 72/72 - 18s - loss: 0.0178 - accuracy: 0.9948 - val_loss: 0.0750 - val_accuracy: 0.9791 - 18s/epoch - 257ms/step
# Epoch 76/100
# 72/72 - 18s - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0737 - val_accuracy: 0.9800 - 18s/epoch - 254ms/step
# Epoch 77/100
# 72/72 - 18s - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0882 - val_accuracy: 0.9830 - 18s/epoch - 253ms/step
# Epoch 78/100
# 72/72 - 19s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0810 - val_accuracy: 0.9830 - 19s/epoch - 260ms/step
# Epoch 79/100
# 72/72 - 19s - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0817 - val_accuracy: 0.9826 - 19s/epoch - 264ms/step
# Epoch 80/100
# 72/72 - 19s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0896 - val_accuracy: 0.9839 - 19s/epoch - 258ms/step
# Epoch 81/100
# 72/72 - 19s - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.1041 - val_accuracy: 0.9813 - 19s/epoch - 263ms/step
# Epoch 82/100
# 72/72 - 19s - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0985 - val_accuracy: 0.9835 - 19s/epoch - 260ms/step
# Epoch 83/100
# 72/72 - 19s - loss: 5.8746e-04 - accuracy: 0.9999 - val_loss: 0.0971 - val_accuracy: 0.9839 - 19s/epoch - 265ms/step
# Epoch 84/100
# 72/72 - 19s - loss: 0.0105 - accuracy: 0.9978 - val_loss: 0.1342 - val_accuracy: 0.9809 - 19s/epoch - 258ms/step
# Epoch 85/100
# 72/72 - 18s - loss: 0.0269 - accuracy: 0.9907 - val_loss: 0.0932 - val_accuracy: 0.9813 - 18s/epoch - 252ms/step
# Epoch 86/100
# 72/72 - 18s - loss: 0.0103 - accuracy: 0.9958 - val_loss: 0.0828 - val_accuracy: 0.9791 - 18s/epoch - 255ms/step
# Epoch 87/100
# 72/72 - 18s - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.0789 - val_accuracy: 0.9796 - 18s/epoch - 246ms/step
# Epoch 88/100
# 72/72 - 18s - loss: 0.0140 - accuracy: 0.9947 - val_loss: 0.0787 - val_accuracy: 0.9830 - 18s/epoch - 253ms/step
# Epoch 89/100
# 72/72 - 18s - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0782 - val_accuracy: 0.9813 - 18s/epoch - 249ms/step
# Epoch 90/100
# 72/72 - 18s - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.1004 - val_accuracy: 0.9800 - 18s/epoch - 256ms/step
# Epoch 91/100
# 72/72 - 18s - loss: 0.0329 - accuracy: 0.9907 - val_loss: 0.0681 - val_accuracy: 0.9839 - 18s/epoch - 250ms/step
# Epoch 92/100
# 72/72 - 18s - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0668 - val_accuracy: 0.9830 - 18s/epoch - 253ms/step
# Epoch 93/100
# 72/72 - 19s - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.0835 - val_accuracy: 0.9848 - 19s/epoch - 261ms/step
# Epoch 94/100
# 72/72 - 19s - loss: 9.3021e-04 - accuracy: 0.9999 - val_loss: 0.0824 - val_accuracy: 0.9843 - 19s/epoch - 259ms/step
# Epoch 95/100
# 72/72 - 19s - loss: 6.0353e-04 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9848 - 19s/epoch - 265ms/step
# Epoch 96/100
# 72/72 - 19s - loss: 4.7680e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9848 - 19s/epoch - 262ms/step
# Epoch 97/100
# 72/72 - 19s - loss: 3.8357e-04 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9848 - 19s/epoch - 266ms/step
# Epoch 98/100
# 72/72 - 19s - loss: 3.1446e-04 - accuracy: 1.0000 - val_loss: 0.0931 - val_accuracy: 0.9843 - 19s/epoch - 267ms/step
# Epoch 99/100
# 72/72 - 19s - loss: 2.6620e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9848 - 19s/epoch - 262ms/step
# Epoch 100/100
# 72/72 - 18s - loss: 2.2543e-04 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 0.9848 - 18s/epoch - 256ms/step
